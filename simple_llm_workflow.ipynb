# %%
from langgraph.graph import StateGraph,START,END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
class LLmstate(TypedDict):
    query:str
    response:str

# %%
def llm_function(state: LLmstate)->LLmstate:
    llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
    question=state['query']
    answer=llm.invoke(question).content
    state['response']=answer

    return state

# %%
#create our graph
graph=StateGraph(LLmstate)

#add node
graph.add_node('llm',llm_function)

#add edges

graph.add_edge(START,'llm')
graph.add_edge('llm',END)

#workflow
workflow=graph.compile()

# %%
initial_state={"query":"What is capital of delhi"}

final_response=workflow.invoke(initial_state)

print(final_response['response'])
# Out:
# Delhi is a unique case because it is itself the **National Capital Territory of India**.
#
# More specifically, **New Delhi** is the official capital of India, and it is located within the larger metropolitan area of Delhi. So, in essence, Delhi (more precisely New Delhi) *is* the capital. It doesn't have a separate capital *of* itself in the way a state has a capital city.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 llm.invoke("What is capital of delhi").content
#
# NameError: name 'llm' is not defined
